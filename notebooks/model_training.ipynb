# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("../data/wing_sensor_data.csv")

# %%
data.head()
data.columns
data.shape
data.info()
data.describe
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FORCE            58 non-null     str
#  1   MAX DEFORMATION  58 non-null     str
#  2   MAX STRESS       58 non-null     str
#  3   MAX STRAIN       58 non-null     float64
#  4   CONDITION        58 non-null     str
#  5   MATERIAL         58 non-null     str
#  6   THICKNESS        58 non-null     str
# dtypes: float64(1), str(6)
# memory usage: 6.0 KB
# <bound method NDFrame.describe of      FORCE MAX DEFORMATION  MAX STRESS  MAX STRAIN CONDITION         MATERIAL  \
# 0    1000N     0.029378 mm  0.5495 MPa    0.000003    Normal            STEEL
# 1    1500N     0.044067 mm  0.82429MPa    0.000004    Normal            STEEL
# 2    2000N     0.058756 mm  1.0991eMPa    0.000005    Normal            STEEL
# 3    2500N     0.073445 mm   1.3738MPa    0.000007    Normal            STEEL
# 4    3000N     0.088134 mm   1.6486MPa    0.000008    Normal            STEEL
# 5    3500N      0.10282 mm   1.9233MPa    0.000010    Normal            STEEL
# 6    4000N      0.11751 mm   2.1981MPa    0.000011    Normal            STEEL
# 7    4500N        0.1322mm   2.4729MPa    0.000012    Normal            STEEL
# 8    5000N       0.14689mm   2.7476MPa    0.000014    Normal            STEEL
# 9    5500N       0.16158mm   3.0224MPa    0.000015   Warning            STEEL
# 10   6000N       0.17627mm   3.2972MPa    0.000017   Warning            STEEL
# 11   6500N       0.19096mm   3.5719MPa    0.000018   Warning            STEEL
# 12   7000N       0.20565mm   3.8467MPa    0.000019   Warning            STEEL
# 13   7500N       0.22033mm   4.1214MPa    0.000021   Warning            STEEL
# 14   8000N       0.23052mm   4.3962MPa    0.000022   Warning            STEEL
# 15   8500N       0.24971mm    4.671MPa    0.000023   Warning            STEEL
# 16   9000N        0.2644mm   4.9457MPa    0.000025   Warning            STEEL
# 17   9500N       0.27909mm   5.2205MPa    0.000026   Warning            STEEL
# 18  10000N       0.29378mm   5.4953MPa    0.000028   Warning            STEEL
# 19  10500N       0.30847mm     5.77MPa    0.000029  Critical            STEEL
# 20  11000N       0.32316mm   6.0448MPa    0.000030  Critical            STEEL
# 21  11500N       0.33785mm   6.3195MPa    0.000032  Critical            STEEL
# 22  12000N       0.35254mm   6.5943MPa    0.000033  Critical            STEEL
# 23  12500N       0.36722mm   6.8691MPa    0.000034  Critical            STEEL
# 24  13000N       0.38191mm   7.1438MPa    0.000036  Critical            STEEL
# 25  13500N        0.3966mm   7.4186MPa    0.000037  Critical            STEEL
# 26  14000N       0.41129mm   7.6934MPa    0.000039  Critical            STEEL
# 27  14500N       0.42598mm   7.9681MPa    0.000040  Critical            STEEL
# 28  15000N       0.44067mm   8.2429MPa    0.000041  Critical            STEEL
# 29   1000N       0.08256mm  0.54865MPa    0.000008    Normal  ALUMINIUM ALLOY
# 30   1500N       0.12384mm  0.82297MPa    0.000012    Normal  ALUMINIUM ALLOY
# 31   2000N       0.16512mm   1.0973MPa    0.000016    Normal  ALUMINIUM ALLOY
# 32   2500N        0.2064mm   1.3716MPa    0.000019    Normal  ALUMINIUM ALLOY
# 33   3000N        0.2478mm   1.6459MPa    0.000023    Normal  ALUMINIUM ALLOY
# 34   3500N       0.28896mm   1.9203MPa    0.000027    Normal  ALUMINIUM ALLOY
# 35   4000N       0.33024mm   2.1946MPa    0.000031    Normal  ALUMINIUM ALLOY
# 36   4500N       0.37152mm   2.4689MPa    0.000035    Normal  ALUMINIUM ALLOY
# 37   5000N        0.4128mm   2.7432MPa    0.000039    Normal  ALUMINIUM ALLOY
# 38   5500N       0.45408mm   3.0176MPa    0.000043   Warning  ALUMINIUM ALLOY
# 39   6000N       0.49536mm   3.2919MPa    0.000046   Warning  ALUMINIUM ALLOY
# 40   6500N       0.53664mm   3.5662MPa    0.000050   Warning  ALUMINIUM ALLOY
# 41   7000N       0.57792mm   3.8405MPa    0.000054   Warning  ALUMINIUM ALLOY
# 42   7500N        0.6192mm   4.1149MPa    0.000058   Warning  ALUMINIUM ALLOY
# 43   8000N       0.66048mm   4.3892MPa    0.000062   Warning  ALUMINIUM ALLOY
# 44   8500N       0.70176mm   4.6635MPa    0.000066   Warning  ALUMINIUM ALLOY
# 45   9000N       0.74304mm   4.9378MPa    0.000070   Warning  ALUMINIUM ALLOY
# 46   9500N       0.78432mm   5.2122MPa    0.000073   Warning  ALUMINIUM ALLOY
# 47  10000N        0.8256mm   5.4865MPa    0.000077   Warning  ALUMINIUM ALLOY
# 48  10500N       0.86688mm   5.7608MPa    0.000081  Critical  ALUMINIUM ALLOY
# 49  11000N       0.90816mm   6.0351MPa    0.000085  Critical  ALUMINIUM ALLOY
# 50  11500N       0.94944mm   6.3095MPa    0.000089  Critical  ALUMINIUM ALLOY
# 51  12000N       0.99072mm   6.5838MPa    0.000093  Critical  ALUMINIUM ALLOY
# 52  12500N         1.032mm   6.8581MPa    0.000097  Critical  ALUMINIUM ALLOY
# 53  13000N        1.0733mm   7.1324MPa    0.000100  Critical  ALUMINIUM ALLOY
# 54  13500N        1.1146mm   7.4068MPa    0.000104  Critical  ALUMINIUM ALLOY
# 55  14000N        1.1558mm   7.6811MPa    0.000108  Critical  ALUMINIUM ALLOY
# 56  14500N        1.1971mm   7.9554MPa    0.000112  Critical  ALUMINIUM ALLOY
# 57  15000N        1.2384mm   8.2297MPa    0.000116  Critical  ALUMINIUM ALLOY
#
#    THICKNESS
# 0    96.16mm
# 1    96.16mm
# 2    96.16mm
# 3    96.16mm
# 4    96.16mm
# 5    96.16mm
# 6    96.16mm
# 7    96.16mm
# 8    96.16mm
# 9    96.16mm
# 10   96.16mm
# 11   96.16mm
# 12   96.16mm
# 13   96.16mm
# 14   96.16mm
# 15   96.16mm
# 16   96.16mm
# 17   96.16mm
# 18   96.16mm
# 19   96.16mm
# 20   96.16mm
# 21   96.16mm
# 22   96.16mm
# 23   96.16mm
# 24   96.16mm
# 25   96.16mm
# 26   96.16mm
# 27   96.16mm
# 28   96.16mm
# 29   96.16mm
# 30   96.16mm
# 31   96.16mm
# 32   96.16mm
# 33   96.16mm
# 34   96.16mm
# 35   96.16mm
# 36   96.16mm
# 37   96.16mm
# 38   96.16mm
# 39   96.16mm
# 40   96.16mm
# 41   96.16mm
# 42   96.16mm
# 43   96.16mm
# 44   96.16mm
# 45   96.16mm
# 46   96.16mm
# 47   96.16mm
# 48   96.16mm
# 49   96.16mm
# 50   96.16mm
# 51   96.16mm
# 52   96.16mm
# 53   96.16mm
# 54   96.16mm
# 55   96.16mm
# 56   96.16mm
# 57   96.16mm  >

# %%
print("Duplicate Rows:", data.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
condition_counts = data["CONDITION"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(condition_counts.index, condition_counts.values)

plt.title("Distribution of Wing Health Conditions")
plt.xlabel("Condition")
plt.ylabel("Number of Samples")

plt.show()
